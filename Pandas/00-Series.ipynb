# %% [markdown]
# <a href='http://moncoachdata.com'><img src= 'https://moncoachdata.com/wp-content/uploads/MonCoachData-cours/MonCoachData.jpg' width=400/></a>
#
#
# ---
#
#
# <center><em>Copyright MonCoachData (tous droits réservés)</em></center>
# <center><em>Pour plus d'informations, visitez notre site <a href='http://moncoachdata.com'>moncoachdata.com</a></em></center>
#
#
#
# ---

# %% [markdown]
# # Series

# %% [markdown]
# Le premier type de données principal que nous apprendrons sur Pandas est le type de données des séries. Importons Pandas et explorons l'objet Series.
#
# Une série est très similaire à un tableau NumPy (en fait, il est construit au-dessus de l'objet array NumPy). Ce qui différencie le tableau NumPy d'une série, c'est qu'une série peut comporter des étiquettes d'axe, ce qui signifie qu'elle peut être indexée par une étiquette, au lieu d'un seul emplacement numérique. Il n'a pas non plus besoin de contenir des données numériques, il peut contenir n'importe quel objet Python arbitraire.
#
# Explorons ce concept à travers quelques exemples :

# %% [markdown]
# ## Importations

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Création d'une série à partir d'objets Python

# %%
# help(pd.Series)

# %% [markdown]
# ### Listes d'index et de données
#
#
# Nous pouvons créer une série à partir de listes Python (également à partir de tableaux NumPy)

# %%
myindex = ['USA','Canada','Mexico']

# %%
mydata = [1776,1867,1821]

# %%
myser = pd.Series(data=mydata)

# %%
myser
# Out:
# 0    1776
# 1    1867
# 2    1821
# dtype: int64

# %%
pd.Series(data=mydata,index=myindex)
# Out:
# USA       1776
# Canada    1867
# Mexico    1821
# dtype: int64

# %%
ran_data = np.random.randint(0,100,4)

# %%
ran_data
# Out:
# array([55, 99, 84, 80])

# %%
names = ['Andrew','Bobo','Claire','David']

# %%
ages = pd.Series(ran_data,names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-eca71569a09c> in <module>
# ----> 1 ages = pd.Series(ran_data,names)
#
# NameError: name 'ran_data' is not defined

# %%
ages
# Out:
# Andrew    55
# Bobo      99
# Claire    84
# David     80
# dtype: int64

# %% [markdown]
# ### À partir d'un dictionnaire

# %%
ages = {'Sammy':5,'Frank':10,'Spike':7}

# %%
ages
# Out:
# {'Frank': 10, 'Sammy': 5, 'Spike': 7}

# %%
pd.Series(ages)
# Out:
# Sammy     5
# Frank    10
# Spike     7
# dtype: int64

# %% [markdown]
# ## Idées clés d'une Série

# %% [markdown]
# ### Index nominatif

# %%
# Données de ventes (inventés) pour les 1er et 2e trimestres pour une entreprise mondiale
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100,'China': 500, 'India': 210,'USA': 260}

# %%
# Convertir en série Pandas
sales_Q1 = pd.Series(q1)
sales_Q2 = pd.Series(q2)

# %%
sales_Q1
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
# Appels de valeurs basés sur l'index nominatif
sales_Q1['Japan']
# Out:
# 80

# %%
# Les informations de localisation basées sur des entiers sont également conservées !
sales_Q1[0]
# Out:
# 80

# %% [markdown]
# **Soyez prudent avec les erreurs potentielles !**

# %%
# Faux nom
# sales_Q1['France']

# %%
# Espace supplémentaire accidentel
# sales_Q1['USA ']

# %%
# Erreur de majuscule
# sales_Q1['usa']

# %% [markdown]
# ### Opérations

# %%
# Saisir uniquement les clés d'index
sales_Q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
# Peut effectuer des opérations diffusées sur l'ensemble de la série
sales_Q1 * 2
# Out:
# Japan    160
# China    900
# India    400
# USA      500
# dtype: int64

# %%
sales_Q2 / 100
# Out:
# Brazil    1.0
# China     5.0
# India     2.1
# USA       2.6
# dtype: float64

# %% [markdown]
# ### Entre séries

# %%
# Remarquez comment Pandas vous informe de l'inadéquation avec NaN.
sales_Q1 + sales_Q2
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
# Vous pouvez les remplacer avec n'importe quelle valeur que vous voulez
sales_Q1.add(sales_Q2,fill_value=0)
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %% [markdown]
# C'est tout ce que nous devons savoir sur l'objet Series, à suivre les DataFrames !
